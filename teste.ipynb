# %%
from src.flowmia import FlowMIA

# %%
config_netshare = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/netshare.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 300, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'results/netshare',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_netshare = FlowMIA(config=config_netshare)
# Out:
# Using device: cuda

# %%
scores = flowmia_netshare.flowmiagan(pre_trained_model='results/netshare/checkpoints/checkpoint_epoch_300.pth', 
                            plot=True)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Model loaded from results/netshare/checkpoints/checkpoint_epoch_300.pth
#   latent_dim=128, input_dim=12, wgan=True
# FlowMIA-GAN results: AUC=0.7506
#   Saved: results/netshare/plots/distributions.pdf
#   Saved: results/netshare/plots/roc_pr.pdf
#   Saved: results/netshare/plots/confusion.pdf

# %%
scores['score_members'].shape
# Out:
# (1000,)

# %%
scores = flowmia_netshare.flowmiagan(plot=True)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Starting GAN training...
# Training GAN:  33%|███▎      | 100/300 [07:10<14:04,  4.22s/epoch, D=0.4446, G=-0.6848, GP=0.0508]
#   Checkpoint saved → results/netshare/checkpoints/checkpoint_epoch_100.pth
# Training GAN:  67%|██████▋   | 200/300 [14:16<07:03,  4.23s/epoch, D=0.0636, G=-0.6551, GP=0.0145]
#   Checkpoint saved → results/netshare/checkpoints/checkpoint_epoch_200.pth
# Training GAN: 100%|██████████| 300/300 [21:21<00:00,  4.27s/epoch, D=0.0202, G=-0.6420, GP=0.0100]
#   Checkpoint saved → results/netshare/checkpoints/checkpoint_epoch_300.pth
# FlowMIA-GAN results: AUC=0.7621
#   Saved: results/netshare/plots/distributions.pdf
#   Saved: results/netshare/plots/roc_pr.pdf
#   Saved: results/netshare/plots/confusion.pdf

# %%
flowmia_netshare.domias(test_size=1000)
# Out:
# Loading dataset..
# Creating directory experiment..
# Creating BNAF model..
# Creating optimizer..
# Creating scheduler..
# Training..
#   0%|                                                   | 0/319 [00:00<?, ?it/s]
# /home/gui751/Documents/TCC_dir/FlowMIA/src/privacy/domias/optim/adam.py:93: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1862.)
#   exp_avg.mul_(beta1).add_(1 - beta1, grad)
# 100%|████████████████████████████| 319/319 [00:14<00:00, 21.53it/s, loss=-12.72]
# Epoch   1/  5 -- train_loss: -7.553 -- validation_loss: 180.299
# Saving model..
# 100%|████████████████████████████| 319/319 [00:14<00:00, 22.16it/s, loss=-28.34]
# Epoch   2/  5 -- train_loss: -19.677 -- validation_loss: 88.668
# Saving model..
# 100%|████████████████████████████| 319/319 [00:14<00:00, 21.96it/s, loss=-14.28]
# Epoch   3/  5 -- train_loss: -22.404 -- validation_loss: 45.480
# Saving model..
# 100%|████████████████████████████| 319/319 [00:14<00:00, 22.01it/s, loss=-27.17]
# Epoch   4/  5 -- train_loss: -23.595 -- validation_loss: 24.162
# Saving model..
# 100%|████████████████████████████| 319/319 [00:14<00:00, 22.03it/s, loss=-26.60]
# Epoch   5/  5 -- train_loss: -25.169 -- validation_loss: 6.243
# Saving model..
# ###### Stop training after 5 epochs!
# Validation loss: 6.243
# Test loss:       -1.349
# DOMIAS results: AUC=0.8107
# (array([ -1.8528595,   1.4906006, -20.747856 , ...,  -6.8989983,
#         -24.29096  ,  -2.776989 ], shape=(2000,), dtype=float32),
#  0.810664)

# %%
flowmia_netshare.compute_dcr()
# Out:
# DCR results: AUC=0.8034
# (array([-0.35773804, -0.21354886, -1.16887988, ..., -0.61894935,
#         -1.71886419, -0.72730477], shape=(2000,)),
#  0.8034350000000001)
