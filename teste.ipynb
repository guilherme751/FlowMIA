# %%
from src.flowmia import FlowMIA

# %% [markdown]
# ### NetShare

# %%
config_netshare = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/netshare.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 300, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'results/netshare',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_netshare = FlowMIA(config=config_netshare)
# Out:
# Using device: cuda

# %%
scores = flowmia_netshare.flowmiagan(pre_trained_model='results/netshare/checkpoints/checkpoint_epoch_300.pth', 
                            plot=True, test_size = 1000)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Model loaded from results/netshare/checkpoints/checkpoint_epoch_300.pth
#   latent_dim=128, input_dim=12, wgan=True
# FlowMIA-GAN results: AUC=0.7506
#   Saved: results/netshare/plots/distributions.pdf
#   Saved: results/netshare/plots/roc_pr.pdf
#   Saved: results/netshare/plots/confusion.pdf

# %%
import numpy as np
scores, auc = flowmia_netshare.domias(test_size=10000, save_path='results/netshare/domias', epochs=30, load=True)

np.save('results/netshare/domias/scores.npy', scores)

# %%
scores = np.load('results/netshare/domias/scores.npy')

# %%
scores, auc = flowmia_netshare.compute_dcr(test_size=10000)
np.save('results/netshare/dcr/scores.npy', scores)
# Out:
# DCR results: AUC=0.8018

# %% [markdown]
# ### CTGAN

# %%
config_ctgan = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/ctgan.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 300, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'results/ctgan',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_ctgan= FlowMIA(config=config_ctgan)
# Out:
# Using device: cuda

# %%
scores = flowmia_ctgan.flowmiagan(plot=True, test_size = 10000)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Starting GAN training...
# Training GAN:  33%|███▎      | 100/300 [06:33<12:59,  3.90s/epoch, D=5.2414, G=-0.4762, GP=0.5357]
#   Checkpoint saved → results/ctgan/checkpoints/checkpoint_epoch_100.pth
# Training GAN:  67%|██████▋   | 200/300 [13:04<06:28,  3.88s/epoch, D=1.9628, G=-0.6314, GP=0.1971]
#   Checkpoint saved → results/ctgan/checkpoints/checkpoint_epoch_200.pth
# Training GAN: 100%|██████████| 300/300 [19:27<00:00,  3.89s/epoch, D=0.2926, G=-0.6681, GP=0.0356]
#   Checkpoint saved → results/ctgan/checkpoints/checkpoint_epoch_300.pth
# FlowMIA-GAN results: AUC=0.5000
#   Saved: results/ctgan/plots/distributions.pdf
#   Saved: results/ctgan/plots/roc_pr.pdf
#   Saved: results/ctgan/plots/confusion.pdf

# %%
scores, auc = flowmia_ctgan.domias(test_size=10000, save_path='results/ctgan/domias', epochs=30, load=True)
np.save('results/ctgan/domias/scores.npy', scores)
# Out:
# Loading dataset..
# Creating directory experiment..
# Creating BNAF model..
# Creating optimizer..
# Creating scheduler..
# Training..
# 100%|██████████████████████████████| 300/300 [00:13<00:00, 23.01it/s, loss=2.47]
# Epoch   1/ 30 -- train_loss: 280.821 -- validation_loss: 6325.846
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 23.02it/s, loss=-16.94]
# Epoch   2/ 30 -- train_loss: 2.318 -- validation_loss: 298.130
# Saving model..
# 100%|████████████████████████████| 300/300 [00:12<00:00, 23.27it/s, loss=-30.43]
# Epoch   3/ 30 -- train_loss: -24.506 -- validation_loss: 59.762
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.99it/s, loss=-37.54]
# Epoch   4/ 30 -- train_loss: -34.226 -- validation_loss: 21.228
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.93it/s, loss=-44.04]
# Epoch   5/ 30 -- train_loss: -40.848 -- validation_loss: 3.473
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-48.78]
# Epoch   6/ 30 -- train_loss: -46.180 -- validation_loss: -14.985
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-52.71]
# Epoch   7/ 30 -- train_loss: -50.904 -- validation_loss: -31.315
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-48.75]
# Epoch   8/ 30 -- train_loss: -54.087 -- validation_loss: -45.340
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-53.94]
# Epoch   9/ 30 -- train_loss: -57.262 -- validation_loss: -54.486
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.89it/s, loss=-60.70]
# Epoch  10/ 30 -- train_loss: -60.529 -- validation_loss: -60.296
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-63.92]
# Epoch  11/ 30 -- train_loss: -63.138 -- validation_loss: -64.349
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-71.21]
# Epoch  12/ 30 -- train_loss: -66.028 -- validation_loss: -67.238
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-68.62]
# Epoch  13/ 30 -- train_loss: -68.566 -- validation_loss: -70.406
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-76.37]
# Epoch  14/ 30 -- train_loss: -71.140 -- validation_loss: -72.859
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.86it/s, loss=-74.18]
# Epoch  15/ 30 -- train_loss: -73.121 -- validation_loss: -75.349
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.88it/s, loss=-76.64]
# Epoch  16/ 30 -- train_loss: -74.253 -- validation_loss: -77.129
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.92it/s, loss=-81.17]
# Epoch  17/ 30 -- train_loss: -78.932 -- validation_loss: -80.061
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 23.02it/s, loss=-82.97]
# Epoch  18/ 30 -- train_loss: -78.770 -- validation_loss: -80.909
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 23.01it/s, loss=-84.41]
# Epoch  19/ 30 -- train_loss: -82.160 -- validation_loss: -83.021
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.99it/s, loss=-91.55]
# Epoch  20/ 30 -- train_loss: -83.347 -- validation_loss: -85.556
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.99it/s, loss=-95.20]
# Epoch  21/ 30 -- train_loss: -85.762 -- validation_loss: -88.267
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.78it/s, loss=-96.73]
# Epoch  22/ 30 -- train_loss: -88.130 -- validation_loss: -90.797
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.14it/s, loss=-91.71]
# Epoch  23/ 30 -- train_loss: -90.687 -- validation_loss: -92.883
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.84it/s, loss=-91.12]
# Epoch  24/ 30 -- train_loss: -91.752 -- validation_loss: -93.956
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 23.00it/s, loss=-91.12]
# Epoch  25/ 30 -- train_loss: -94.116 -- validation_loss: -96.630
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.99it/s, loss=-96.59]
# Epoch  26/ 30 -- train_loss: -96.227 -- validation_loss: -98.886
# Saving model..
# 100%|███████████████████████████| 300/300 [00:12<00:00, 23.20it/s, loss=-106.46]
# Epoch  27/ 30 -- train_loss: -98.149 -- validation_loss: -101.261
# Saving model..
# 100%|███████████████████████████| 300/300 [00:13<00:00, 22.98it/s, loss=-101.11]
# Epoch  28/ 30 -- train_loss: -100.557 -- validation_loss: -103.781
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.98it/s, loss=-97.75]
# Epoch  29/ 30 -- train_loss: -100.998 -- validation_loss: -104.009
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 23.00it/s, loss=-95.57]
# Epoch  30/ 30 -- train_loss: -103.586 -- validation_loss: -106.445
# Saving model..
# ###### Stop training after 30 epochs!
# Validation loss: -106.445
# Test loss:       -106.626
# DOMIAS results: AUC=0.7385

# %%
scores, auc = flowmia_ctgan.compute_dcr(test_size=10000)
np.save('results/ctgan/dcr/scores.npy', scores)
# Out:
# DCR results: AUC=0.6433

# %% [markdown]
# ### Tabula

# %%
config_tabula = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/tabula.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 300, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'results/tabula',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_tabula = FlowMIA(config=config_tabula)
# Out:
# Using device: cuda

# %%
scores = flowmia_tabula.flowmiagan(plot=True, test_size = 10000)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Starting GAN training...
# Training GAN:  33%|███▎      | 100/300 [06:22<12:44,  3.82s/epoch, D=4.9488, G=-0.5353, GP=0.4965]
#   Checkpoint saved → results/tabula/checkpoints/checkpoint_epoch_100.pth
# Training GAN:  67%|██████▋   | 200/300 [12:45<06:27,  3.87s/epoch, D=0.0661, G=-0.5996, GP=0.0178]
#   Checkpoint saved → results/tabula/checkpoints/checkpoint_epoch_200.pth
# Training GAN: 100%|██████████| 300/300 [19:12<00:00,  3.84s/epoch, D=0.0318, G=-0.6740, GP=0.0081]
#   Checkpoint saved → results/tabula/checkpoints/checkpoint_epoch_300.pth
# FlowMIA-GAN results: AUC=0.8340
#   Saved: results/tabula/plots/distributions.pdf
#   Saved: results/tabula/plots/roc_pr.pdf
#   Saved: results/tabula/plots/confusion.pdf

# %%
scores, auc = flowmia_tabula.domias(test_size=10000, save_path='results/tabula/domias', epochs=30, load=True)
np.save('results/tabula/domias/scores.npy', scores)
# Out:
# Loading dataset..
# Creating directory experiment..
# Creating BNAF model..
# Creating optimizer..
# Creating scheduler..
# Training..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.80it/s, loss=-22.73]
# Epoch   1/ 30 -- train_loss: -11.094 -- validation_loss: 196.482
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.65it/s, loss=-25.94]
# Epoch   2/ 30 -- train_loss: -24.413 -- validation_loss: 88.187
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.54it/s, loss=-33.14]
# Epoch   3/ 30 -- train_loss: -28.999 -- validation_loss: 50.831
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.29it/s, loss=-38.36]
# Epoch   4/ 30 -- train_loss: -32.877 -- validation_loss: 27.606
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.32it/s, loss=-42.36]
# Epoch   5/ 30 -- train_loss: -37.866 -- validation_loss: 7.529
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.13it/s, loss=-39.46]
# Epoch   6/ 30 -- train_loss: -41.182 -- validation_loss: -12.763
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.84it/s, loss=-45.46]
# Epoch   7/ 30 -- train_loss: -42.519 -- validation_loss: -29.452
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.80it/s, loss=-40.56]
# Epoch   8/ 30 -- train_loss: -44.912 -- validation_loss: -40.817
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.88it/s, loss=-39.79]
# Epoch   9/ 30 -- train_loss: -45.312 -- validation_loss: -48.059
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.87it/s, loss=-46.94]
# Epoch  10/ 30 -- train_loss: -48.711 -- validation_loss: -51.596
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.78it/s, loss=-52.33]
# Epoch  11/ 30 -- train_loss: -53.824 -- validation_loss: -54.400
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.80it/s, loss=-64.24]
# Epoch  12/ 30 -- train_loss: -57.598 -- validation_loss: -58.409
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.85it/s, loss=-64.00]
# Epoch  13/ 30 -- train_loss: -61.231 -- validation_loss: -62.522
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.90it/s, loss=-64.12]
# Epoch  14/ 30 -- train_loss: -63.352 -- validation_loss: -65.559
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.88it/s, loss=-64.87]
# Epoch  15/ 30 -- train_loss: -66.346 -- validation_loss: -68.899
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.83it/s, loss=-75.25]
# Epoch  16/ 30 -- train_loss: -69.124 -- validation_loss: -72.116
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.88it/s, loss=-72.58]
# Epoch  17/ 30 -- train_loss: -70.480 -- validation_loss: -74.601
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 21.83it/s, loss=-75.30]
# Epoch  18/ 30 -- train_loss: -71.506 -- validation_loss: -76.047
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.49it/s, loss=-71.94]
# Epoch  19/ 30 -- train_loss: -73.015 -- validation_loss: -78.209
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.40it/s, loss=-79.45]
# Epoch  20/ 30 -- train_loss: -77.898 -- validation_loss: -81.229
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.40it/s, loss=-83.10]
# Epoch  21/ 30 -- train_loss: -77.960 -- validation_loss: -83.076
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.36it/s, loss=-81.24]
# Epoch  22/ 30 -- train_loss: -80.340 -- validation_loss: -85.066
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.33it/s, loss=-85.34]
# Epoch  23/ 30 -- train_loss: -83.303 -- validation_loss: -87.526
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.30it/s, loss=-87.07]
# Epoch  24/ 30 -- train_loss: -83.576 -- validation_loss: -86.504
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.40it/s, loss=-82.69]
# Epoch  25/ 30 -- train_loss: -85.814 -- validation_loss: -89.268
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.35it/s, loss=-84.78]
# Epoch  26/ 30 -- train_loss: -86.109 -- validation_loss: -91.378
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.35it/s, loss=-89.61]
# Epoch  27/ 30 -- train_loss: -87.003 -- validation_loss: -92.938
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.39it/s, loss=-80.59]
# Epoch  28/ 30 -- train_loss: -90.591 -- validation_loss: -95.115
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.40it/s, loss=-84.74]
# Epoch  29/ 30 -- train_loss: -89.577 -- validation_loss: -95.170
# Saving model..
# 100%|████████████████████████████| 300/300 [00:13<00:00, 22.35it/s, loss=-97.65]
# Epoch  30/ 30 -- train_loss: -94.451 -- validation_loss: -98.305
# Saving model..
# ###### Stop training after 30 epochs!
# Validation loss: -98.305
# Test loss:       -98.605
# DOMIAS results: AUC=0.9571

# %%
scores, auc = flowmia_tabula.compute_dcr(test_size=10000)
np.save('results/tabula/dcr/scores.npy', scores)
# Out:
# DCR results: AUC=0.9670
