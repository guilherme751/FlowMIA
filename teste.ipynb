# %%
from src.flowmia import FlowMIA

# %%
import pandas as pd
import ipaddress

def split_ip_columns(df, ip_cols=("srcip", "dstip")):
	df = df.copy()

	for col in ip_cols:
		# Converte inteiro → IPv4 string
		ip_str = df[col].apply(lambda x: str(ipaddress.IPv4Address(int(x))))

		# Split em 4 octetos
		octets = ip_str.str.split(".", expand=True).astype(int)
		octets.columns = [f"{col}_{i}" for i in range(1, 5)]

		# Adiciona ao dataframe
		df = pd.concat([df, octets], axis=1)

	df = df.drop(columns=list(ip_cols))

	return df

# %%
df = split_ip_columns(pd.read_csv('datasets/real/cidds_train.csv'))
df.to_csv('datasets2/real/cidds_train.csv', index=False)

df = split_ip_columns(pd.read_csv('datasets/real/cidds_test.csv'))
df.to_csv('datasets2/real/cidds_test.csv', index=False)

df = split_ip_columns(pd.read_csv('datasets/synthetic/tabula.csv'))
df.to_csv('datasets2/synthetic/tabula.csv', index=False)

df = split_ip_columns(pd.read_csv('datasets/synthetic/netshare.csv'))
df.to_csv('datasets2/synthetic/netshare.csv', index=False)

df = split_ip_columns(pd.read_csv('datasets/synthetic/ctgan.csv'))
df.to_csv('datasets2/synthetic/ctgan.csv', index=False)

df = split_ip_columns(pd.read_csv('datasets/reference/ton.csv'))
df.to_csv('datasets2/reference/ton.csv', index=False)

# %%
df = split_ip_columns(df)

# %%
df['srcip_1'].unique()
# Out:
# array([192,   0])

# %% [markdown]
# ### NetShare

# %%
config_netshare = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/netshare.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 1000, # número de amostrar por lote
    'num_epochs': 100, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'resultados_oficiais/netshare',    # pasta para salvar resultados
    'use_wgan': True, # se deve usar WGAN ou GAN tradicional
    'test_size': 10000
}

# %%
flowmia_netshare = FlowMIA(config=config_netshare)
# Out:
# Using device: cuda
# (15911, 9) (65000, 9)
# (80911, 9)
# [[0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.75256944 0.7525766 ]
#  ...
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]]
# [[0.01358325 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  ...
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]]
# [[0.24742341 0.24743056]
#  [0.75257564 0.9999999 ]
#  [0.75257564 0.9403533 ]
#  ...
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]]
# (65000, 10) (64998, 10) (15911, 10)

# %%
scores = flowmia_netshare.flowmiagan(test_size = config_netshare['test_size'])
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Starting GAN training...
# ...
# Training GAN: 100%|██████████| 100/100 [01:29<00:00,  1.11epoch/s, D=-0.1713, G=0.1692, GP=0.0152]
#   Checkpoint saved → resultados_oficiais/netshare/checkpoints/checkpoint_epoch_100.pth
# (10000,)
# FlowMIA-GAN results: AUC=0.8902

# %%
import numpy as np
scores, auc = flowmia_netshare.domias(test_size=config_netshare['test_size'], save_path='results/netshare/domias', epochs=30, load=True)
np.save('resultados_oficiais/netshare/domias/scores.npy', scores)

# %%
scores, auc = flowmia_netshare.compute_dcr(test_size=config_netshare['test_size'])
np.save('resultados_oficiais/netshare/dcr/scores.npy', scores)
# Out:
# DCR results: AUC=0.9103

# %%
from sklearn.metrics import roc_auc_score, roc_curve
scores_flowmiagan = np.concatenate([scores['score_members'], scores['score_non_members']])
scores_domias = np.load('results/netshare/domias/scores.npy')
scores_dcr = np.load('results/netshare/dcr/scores.npy')

y_test = np.concatenate([np.ones(config_netshare['test_size']), np.zeros(config_netshare['test_size'])])

auc_flowmiagan_netshare = roc_auc_score(y_test, scores_flowmiagan)
roc_flowmiagan_netshare = roc_curve(y_test, scores_flowmiagan)
auc_domias_netshare = roc_auc_score(y_test, scores_domias)
roc_domias_netshare = roc_curve(y_test, scores_domias)
auc_dcr_netshare = roc_auc_score(y_test, scores_dcr)
roc_dcr_netshare = roc_curve(y_test, scores_dcr)

# %%
print(f"AUC FlowMIA-GAN: {auc_flowmiagan_netshare:.4f}")
print(f"AUC DOMIAS: {auc_domias_netshare:.4f}")
print(f"AUC DCR: {auc_dcr_netshare:.4f}")
# Out:
# AUC FlowMIA-GAN: 0.8902
# AUC DOMIAS: 0.8366
# AUC DCR: 0.8018

# %% [markdown]
# ### CTGAN

# %%
config_ctgan = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/ctgan.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'pkt', 'td', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 1000, # número de amostrar por lote
    'num_epochs': 100, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'resultados_oficiais/ctgan',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_ctgan= FlowMIA(config=config_ctgan)
# Out:
# Using device: cuda
# (15000, 9) (65000, 9)
# (80000, 9)
# [[0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.75256944 0.7525766 ]
#  ...
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]]
# [[0.01358325 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  ...
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]]
# [[0.7525749  0.75257206]
#  [0.7525763  0.75257206]
#  [0.7525748  0.7525727 ]
#  ...
#  [0.75257605 0.75257206]
#  [0.7525748  0.7525721 ]
#  [0.75257564 0.75257206]]
# (65000, 10) (64998, 10) (15000, 10)

# %%
scores = flowmia_ctgan.flowmiagan(test_size = 10000)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Starting GAN training...
# Training GAN: 100%|██████████| 100/100 [01:24<00:00,  1.19epoch/s, D=-0.1570, G=-0.3833, GP=0.0143]
#   Checkpoint saved → resultados_oficiais/ctgan/checkpoints/checkpoint_epoch_100.pth
# (10000,)
# FlowMIA-GAN results: AUC=0.8520

# %%
scores, auc = flowmia_ctgan.domias(test_size=10000, save_path='results/ctgan/domias', epochs=30, load=True)
np.save('results/ctgan/domias/scores.npy', scores)

# %%
scores, auc = flowmia_ctgan.compute_dcr(test_size=10000)
np.save('test/ctgan/dcr/scores.npy', scores)
# Out:
# DCR results: AUC=0.6925

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import numpy as np
scores_flowmiagan = np.concatenate([scores['score_members'], scores['score_non_members']])
scores_domias = np.load('resultados_oficiais/ctgan/domias/scores.npy')
scores_dcr = np.load('resultados_oficiais/ctgan/dcr/scores.npy')

y_test = np.concatenate([np.ones(10000), np.zeros(10000)])

auc_flowmiagan_ctgan = roc_auc_score(y_test, scores_flowmiagan)
roc_flowmiagan_ctgan = roc_curve(y_test, scores_flowmiagan)
auc_domias_ctgan = roc_auc_score(y_test, scores_domias)
roc_domias_ctgan = roc_curve(y_test, scores_domias)
auc_dcr_ctgan = roc_auc_score(y_test, scores_dcr)
roc_dcr_ctgan = roc_curve(y_test, scores_dcr)

# %%
print(f"AUC FlowMIA-GAN: {auc_flowmiagan_ctgan:.4f}")
print(f"AUC DOMIAS: {auc_domias_ctgan:.4f}")
print(f"AUC DCR: {auc_dcr_ctgan:.4f}")
# Out:
# AUC FlowMIA-GAN: 0.8520
# AUC DOMIAS: 0.7385
# AUC DCR: 0.6433

# %% [markdown]
# ### Tabula

# %%
from src.flowmia import FlowMIA

# %%
config_tabula = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/tabula.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 1000, # número de amostrar por lote
    'num_epochs': 50, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'resultados_oficiais/tabula',    # pasta para salvar resultados
    'use_wgan': True, # se deve usar WGAN ou GAN tradicional
    'test_size': 10000
}

# %%
flowmia_tabula = FlowMIA(config=config_tabula)
# Out:
# Using device: cuda
# (15000, 9) (65000, 9)
# (80000, 9)
# [[0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.75256944 0.7525766 ]
#  ...
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]]
# [[0.01358325 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  ...
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]
#  [0.75256354 0.7525636 ]]
# [[0.7525766  0.75256944]
#  [0.7525766  0.75256944]
#  [0.75256944 0.7525766 ]
#  ...
#  [0.75256944 0.7525754 ]
#  [0.7525766  0.75256944]
#  [0.7525766  0.75256944]]
# (65000, 10) (64998, 10) (15000, 10)

# %%
scores = flowmia_tabula.flowmiagan(test_size = 10000)
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Starting GAN training...
# Training GAN: 100%|██████████| 50/50 [00:40<00:00,  1.22epoch/s, D=-0.0907, G=-0.1574, GP=0.0144]
#   Checkpoint saved → resultados_oficiais/tabula/checkpoints/checkpoint_epoch_50.pth
# (10000,)
# FlowMIA-GAN results: AUC=0.9084

# %%
flowmia_tabula.flowmiagan(test_size = 10000, pre_trained_model='results/tabula/checkpoints/checkpoint_epoch_300.pth')
# Out:
# Starting FlowMIA-GAN privacy evaluation...
# Model loaded from results/tabula/checkpoints/checkpoint_epoch_300.pth
#   latent_dim=128, input_dim=10, wgan=True
# (10000,)
# FlowMIA-GAN results: AUC=0.3983
# {'score_members': array([-0.10527019, -0.32510376, -0.05654253, ...,  0.38529557,
#         -0.03435811, -0.04454939], shape=(10000,), dtype=float32),
#  'score_non_members': array([-3.4878537e-02, -2.0017266e-02,  1.2187573e+04, ...,
#          3.2921970e-02, -3.5084158e-02, -3.2341048e-02],
#        shape=(10000,), dtype=float32),
#  'score_synthetic': array([-0.37410218, -0.30230618,  0.27706313, ...,  0.03057696,
#         -0.22098736, -0.36524463], shape=(15000,), dtype=float32),
#  'score_random': array([ 0.03295596,  0.00987016,  0.25810862, ...,  0.02044554,
#         -0.09865275,  0.03317682], shape=(15000,), dtype=float32),
#  'auc': 0.39826909499999996,
#  'accuracy': 0.47925,
#  'precision': 0.1452991452991453,
#  'recall': 0.0085,
#  'f1_score': 0.01606046291922532,
# ...

# %%
scores, auc = flowmia_tabula.domias(test_size=10000, save_path='results/tabula/domias', epochs=30, load=True)
np.save('results/tabula/domias/scores.npy', scores)

# %%
scores, auc = flowmia_tabula.compute_dcr(test_size=10000)
np.save('results/tabula/dcr/scores.npy', scores)

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import numpy as np
scores_flowmiagan = np.concatenate([scores['score_members'], scores['score_non_members']])
scores_domias = np.load('resultados_oficiais/tabula/domias/scores.npy')
scores_dcr = np.load('resultados_oficiais/tabula/dcr/scores.npy')

y_test = np.concatenate([np.ones(config_tabula['test_size']), np.zeros(config_tabula['test_size'])])

auc_flowmiagan_tabula = roc_auc_score(y_test, scores_flowmiagan)
roc_flowmiagan_tabula = roc_curve(y_test, scores_flowmiagan)
auc_domias_tabula = roc_auc_score(y_test, scores_domias)
roc_domias_tabula = roc_curve(y_test, scores_domias)
auc_dcr_tabula = roc_auc_score(y_test, scores_dcr)
roc_dcr_tabula = roc_curve(y_test, scores_dcr)

# %%
print(f"AUC FlowMIA-GAN: {auc_flowmiagan_tabula:.4f}")
print(f"AUC DOMIAS: {auc_domias_tabula:.4f}")
print(f"AUC DCR: {auc_dcr_tabula:.4f}")
# Out:
# AUC FlowMIA-GAN: 0.9084
# AUC DOMIAS: 0.9571
# AUC DCR: 0.9670

# %%
attacks = ['FlowMIA-GAN', 'DOMIAS', 'DCR']
aucs = {
	'FlowMIA-GAN': [auc_flowmiagan_ctgan, auc_flowmiagan_netshare, auc_flowmiagan_tabula],
	'DOMIAS': [auc_domias_ctgan, auc_domias_netshare, auc_domias_tabula],
	'DCR': [auc_dcr_ctgan, auc_dcr_netshare, auc_dcr_tabula]	
}

roc_curves = {
	'FlowMIA-GAN': [roc_flowmiagan_ctgan, roc_flowmiagan_netshare, roc_flowmiagan_tabula],
	'DOMIAS': [roc_domias_ctgan, roc_domias_netshare, roc_domias_tabula],
	'DCR': [roc_dcr_ctgan, roc_dcr_netshare, roc_dcr_tabula]
}

# %%
roc_flowmiagan_ctgan[0][2], roc_flowmiagan_netshare[0][2], roc_flowmiagan_tabula[0][2]
# Out:
# (np.float64(0.0008), np.float64(0.0008), np.float64(0.0008))

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['CTGAN', 'NetShare', 'Tabula']
attacks = list(aucs.keys())

# posição das barras
x = np.arange(len(attacks))
width = 0.25

plt.figure()

# plot das barras (uma por modelo)
for i, model in enumerate(models):
    values = [aucs[attack][i] for attack in attacks]
    plt.bar(x + i*width, values, width, label=model)

# ajustes
plt.xticks(x + width, attacks)
plt.ylabel('AUC')
plt.legend(loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt

models = ['CTGAN', 'NetShare', 'Tabula']

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for ax, (attack_name, roc_list) in zip(axes, roc_curves.items()):
    
    for model_name, (fpr, tpr, _) in zip(models, roc_list):
        ax.plot(fpr, tpr, label=model_name)

    # linha aleatória
    ax.plot([0, 1], [0, 1], linestyle='--')
    
    ax.set_title(attack_name)
    ax.set_xlabel('FPR')
    ax.set_ylabel('TPR')
    ax.legend()

plt.tight_layout()

plt.savefig('roc_curves.pdf')
