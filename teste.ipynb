# %%
from src.flowmia import FlowMIA

# %%
config_netshare = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/netshare.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 300, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'teste2/netshare',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_netshare = FlowMIA(config=config_netshare)

# %%
scores = flowmia_netshare.flowmiagan()
# Out:
# Starting FlowMIA privacy evaluation...
# Training FlowMIA GAN...
# Fitting the preprocessors...
# Preprocessors fitted. Starting GAN training...
# Training GAN:   0%|          | 0/300 [00:00<?, ?epoch/s]
# Training GAN:  33%|███▎      | 100/300 [07:45<15:27,  4.64s/epoch, D_loss=0.2979, G_loss=-0.7170, GP=0.0321]
# ✓ Model checkpoint 100 saved to teste2/netshare/checkpoints/checkpoint_epoch_100.pth
# Training GAN:  67%|██████▋   | 200/300 [15:32<07:45,  4.65s/epoch, D_loss=0.0691, G_loss=-0.6713, GP=0.0132]
# ✓ Model checkpoint 200 saved to teste2/netshare/checkpoints/checkpoint_epoch_200.pth
# Training GAN: 100%|██████████| 300/300 [23:19<00:00,  4.66s/epoch, D_loss=0.0149, G_loss=-0.6277, GP=0.0102]
# ✓ Model checkpoint 300 saved to teste2/netshare/checkpoints/checkpoint_epoch_300.pth
#
# Calibrating on reference dataset...
# FlowMIA GAN inference results: {'score_members': array([0.6966751 , 0.6966751 , 0.9039782 , ..., 0.58667463, 0.58704257,
#        0.58704257], shape=(65000,), dtype=float32), 'score_non_members': array([1.        , 0.03001546, 0.03346525, ..., 0.9139308 , 0.9139301 ,
#        0.91392565], shape=(64998,), dtype=float32), 'score_random': array([0.29619184, 0.16457365, 0.13411641, ..., 0.0895523 , 0.18347684,
#        0.51549447], shape=(15911,), dtype=float32), 'score_synthetic': array([0.7897893 , 0.8172038 , 0.81403935, ..., 0.6927302 , 0.61258745,
#        0.59936035], shape=(15911,), dtype=float32), 'auc': 0.7466294192484029, 'accuracy': 0.479891998338436, 'precision': np.float64(0.16387959866220736), 'recall': np.float64(0.0098), 'f1_score': np.float64(0.018494055482166448), 'threshold': np.float32(0.9751532), 'threshold_method': 'statistical', 'mean_score_members': np.float32(0.6826144), 'mean_score_non_members': np.float32(0.3227254), 'mean_score_random': np.float32(0.25245702), 'mean_score_synthetic': np.float32(0.70031494), 'std_score_members': np.float32(0.14214449), 'std_score_non_members': np.float32(0.34624654), 'std_score_random': np.float32(0.25245702), 'std_score_synthetic': np.float32(0.115865566), 'score_gap_member_non_member': np.float32(0.359889), 'score_gap_member_random': np.float32(0.43015736), 'score_gap_member_synthetic': np.float32(-0.017700553), 'privacy_risk_score': np.float32(1.0259305), 'wasserstein_member_synthetic': np.float64(0.0368905438087422), 'wasserstein_nonmember_synthetic': np.float64(0.38723387758994876), 'tp': np.int64(637), 'fp': np.int64(3250), 'tn': np.int64(61748), 'fn': np.int64(64363)}

# %%
scores_netshare = flowmia_netshare.flowmiagan(pre_trained_model='teste2/netshare/checkpoints/checkpoint_epoch_80.pth', plot=True)
# Out:
# Starting FlowMIA privacy evaluation...
# Training FlowMIA GAN...
# ✓ Model loaded from teste2/netshare/checkpoints/checkpoint_epoch_80.pth
#   - Latent dim: 128
#   - Encoded dim: (15911, 12)
#   - WGAN mode: True
#   - Device: cuda
# FlowMIA GAN inference results: {'score_members': array([0.19942646, 0.19942646, 0.8772819 , ..., 0.6462121 , 0.65804565,
#        0.65804565], shape=(65000,), dtype=float32), 'score_non_members': array([1.        , 0.05018448, 0.06033507, ..., 0.9252927 , 0.92526215,
#        0.92506045], shape=(64998,), dtype=float32), 'score_random': array([0.32375774, 0.27024716, 0.26577652, ..., 0.26599297, 0.25455114,
#        0.34158534], shape=(15911,), dtype=float32), 'score_synthetic': array([0.9503699 , 0.74130887, 0.5949494 , ..., 0.6271876 , 0.6420101 ,
#        0.6631448 ], shape=(15911,), dtype=float32), 'auc': 0.7614427743338849, 'accuracy': 0.4802920044923768, 'precision': np.float64(0.17491749174917492), 'recall': np.float64(0.0106), 'f1_score': np.float64(0.019988685649632285), 'threshold': np.float32(0.9993317), 'threshold_method': 'statistical', 'mean_score_members': np.float32(0.55234855), 'mean_score_non_members': np.float32(0.3137652), 'mean_score_random': np.float32(0.27776983), 'mean_score_synthetic': np.float32(0.65707874), 'std_score_members': np.float32(0.26329517), 'std_score_non_members': np.float32(0.308734), 'std_score_random': np.float32(0.27776983), 'std_score_synthetic': np.float32(0.11400931), 'score_gap_member_non_member': np.float32(0.23858336), 'score_gap_member_random': np.float32(0.27457872), 'score_gap_member_synthetic': np.float32(-0.10473019), 'privacy_risk_score': np.float32(1.1896089), 'wasserstein_member_synthetic': np.float64(0.14841758764853524), 'wasserstein_nonmember_synthetic': np.float64(0.3717856322599284), 'tp': np.int64(689), 'fp': np.int64(3250), 'tn': np.int64(61748), 'fn': np.int64(64311)}
# Generating Plot 1: Score Distributions...
# Generating Plot 2: ROC and PR Curves...
# Generating Plot 3: Confusion Matrix...
# Saved: teste2/netshare/plots/distributions.pdf
# Saved: teste2/netshare/plots/roc_pr.pdf
# Saved: teste2/netshare/plots/confusion.pdf

# %%
flowmia_netshare.mia_results
# Out:
# {'score_members': array([0.22842349, 0.22842349, 0.90106946, ..., 0.81467277, 0.8127162 ,
#         0.8127162 ], shape=(65000,), dtype=float32),
#  'score_non_members': array([1.        , 0.01426954, 0.01906594, ..., 0.9203297 , 0.920204  ,
#         0.9193832 ], shape=(64998,), dtype=float32),
#  'score_random': array([0.18239546, 0.19130021, 0.06537122, ..., 0.1710083 , 0.0661426 ,
#         0.5047198 ], shape=(15911,), dtype=float32),
#  'score_synthetic': array([0.97082496, 0.68989515, 0.6231281 , ..., 0.75672996, 0.7143463 ,
#         0.75171036], shape=(15911,), dtype=float32),
#  'auc': 0.7850299139381803,
#  'accuracy': 0.48072278035046695,
#  'precision': np.float64(0.18648310387984982),
#  'recall': np.float64(0.011461538461538462),
#  'f1_score': np.float64(0.02159576780926154),
#  'threshold': np.float32(0.995487),
#  'threshold_method': 'statistical',
#  'mean_score_members': np.float32(0.682921),
#  'mean_score_non_members': np.float32(0.3421309),
#  'mean_score_random': np.float32(0.19126639),
#  'mean_score_synthetic': np.float32(0.74380267),
#  'std_score_members': np.float32(0.25193065),
#  'std_score_non_members': np.float32(0.3725199),
#  'std_score_random': np.float32(0.19126639),
#  'std_score_synthetic': np.float32(0.0881784),
#  'score_gap_member_non_member': np.float32(0.3407901),
#  'score_gap_member_random': np.float32(0.4916546),
#  'score_gap_member_synthetic': np.float32(-0.060881674),
#  'privacy_risk_score': np.float32(1.0891489),
#  'wasserstein_member_synthetic': np.float64(0.12382262634880312),
#  'wasserstein_nonmember_synthetic': np.float64(0.42370182848985516),
#  'tp': np.int64(745),
#  'fp': np.int64(3250),
#  'tn': np.int64(61748),
#  'fn': np.int64(64255)}

# %%
config_ctgan= {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/ctgan.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 100, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'teste/ctgan',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_ctgan = FlowMIA(config=config_ctgan)

# %%
flowmia_ctgan.flowmiagan(plot=True)
# Out:
# Starting FlowMIA privacy evaluation...
# Training FlowMIA GAN...
# Fitting the preprocessors...
# Preprocessors fitted. Starting GAN training...
# Training GAN: 100%|██████████| 100/100 [07:20<00:00,  4.41s/epoch, D_loss=0.8111, G_loss=-0.6987, GP=0.0807]
# ✓ Model checkpoint 100 saved to teste/ctgan/checkpoints/checkpoint_epoch_100.pth
#
# Calibrating on reference dataset...
# FlowMIA GAN inference results: {'score_members': array([0.5990563 , 0.5990563 , 0.91208935, ..., 0.7029759 , 0.6993162 ,
#        0.6993162 ], shape=(65000,), dtype=float32), 'score_non_members': array([1.        , 0.04033547, 0.06258882, ..., 0.91529906, 0.91455543,
#        0.9090176 ], shape=(64998,), dtype=float32), 'score_random': array([0.09071165, 0.24185513, 0.2626578 , ..., 0.18689385, 0.16492422,
#        0.11470227], shape=(15000,), dtype=float32), 'score_synthetic': array([0.6981799 , 0.6406039 , 0.79148877, ..., 0.6682005 , 0.63604134,
#        0.6962618 ], shape=(15000,), dtype=float32), 'auc': 0.8260135889388314, 'accuracy': 0.4804843151433099, 'precision': np.float64(0.18012108980827446), 'recall': np.float64(0.010984615384615384), 'f1_score': np.float64(0.020706455542021926), 'threshold': np.float32(0.9985413), 'threshold_method': 'statistical', 'mean_score_members': np.float32(0.6689031), 'mean_score_non_members': np.float32(0.27362838), 'mean_score_random': np.float32(0.21275124), 'mean_score_synthetic': np.float32(0.7114166), 'std_score_members': np.float32(0.20213635), 'std_score_non_members': np.float32(0.31516558), 'std_score_random': np.float32(0.21275124), 'std_score_synthetic': np.float32(0.09266883), 'score_gap_member_non_member': np.float32(0.39527473), 'score_gap_member_random': np.float32(0.45615187), 'score_gap_member_synthetic': np.float32(-0.04251349), 'privacy_risk_score': np.float32(1.063557), 'wasserstein_member_synthetic': np.float64(0.09130269472567507), 'wasserstein_nonmember_synthetic': np.float64(0.46289951203662616), 'tp': np.int64(714), 'fp': np.int64(3250), 'tn': np.int64(61748), 'fn': np.int64(64286)}
# Generating Plot 1: Score Distributions...
# Generating Plot 2: ROC and PR Curves...
# Generating Plot 3: Confusion Matrix...
# Saved: teste/ctgan/plots/distributions.pdf
# Saved: teste/ctgan/plots/roc_pr.pdf
# Saved: teste/ctgan/plots/confusion.pdf
# {'score_members': array([0.5990563 , 0.5990563 , 0.91208935, ..., 0.7029759 , 0.6993162 ,
#         0.6993162 ], shape=(65000,), dtype=float32),
#  'score_non_members': array([1.        , 0.04033547, 0.06258882, ..., 0.91529906, 0.91455543,
#         0.9090176 ], shape=(64998,), dtype=float32),
#  'score_random': array([0.09071165, 0.24185513, 0.2626578 , ..., 0.18689385, 0.16492422,
#         0.11470227], shape=(15000,), dtype=float32),
#  'score_synthetic': array([0.6981799 , 0.6406039 , 0.79148877, ..., 0.6682005 , 0.63604134,
#         0.6962618 ], shape=(15000,), dtype=float32),
#  'auc': 0.8260135889388314,
#  'accuracy': 0.4804843151433099,
#  'precision': np.float64(0.18012108980827446),
#  'recall': np.float64(0.010984615384615384),
#  'f1_score': np.float64(0.020706455542021926),
#  'threshold': np.float32(0.9985413),
#  'threshold_method': 'statistical',
#  'mean_score_members': np.float32(0.6689031),
#  'mean_score_non_members': np.float32(0.27362838),
#  'mean_score_random': np.float32(0.21275124),
#  'mean_score_synthetic': np.float32(0.7114166),
#  'std_score_members': np.float32(0.20213635),
#  'std_score_non_members': np.float32(0.31516558),
#  'std_score_random': np.float32(0.21275124),
#  'std_score_synthetic': np.float32(0.09266883),
#  'score_gap_member_non_member': np.float32(0.39527473),
#  'score_gap_member_random': np.float32(0.45615187),
#  'score_gap_member_synthetic': np.float32(-0.04251349),
#  'privacy_risk_score': np.float32(1.063557),
#  'wasserstein_member_synthetic': np.float64(0.09130269472567507),
#  'wasserstein_nonmember_synthetic': np.float64(0.46289951203662616),
#  'tp': np.int64(714),
#  'fp': np.int64(3250),
#  'tn': np.int64(61748),
#  'fn': np.int64(64286)}

# %%
config_tabula = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/tabula.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 100, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'teste2/tabula',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
flowmia_tabula = FlowMIA(config=config_tabula)

# %%
flowmia_tabula.flowmiagan(plot=True)
# Out:
# Starting FlowMIA privacy evaluation...
# Training FlowMIA GAN...
# Fitting the preprocessors...
# Preprocessors fitted. Starting GAN training...
# Training GAN: 100%|██████████| 100/100 [07:19<00:00,  4.40s/epoch, D_loss=0.3722, G_loss=-0.4000, GP=0.0737]
# ✓ Model checkpoint 100 saved to teste/ctgan/checkpoints/checkpoint_epoch_100.pth
#
# Calibrating on reference dataset...
# FlowMIA GAN inference results: {'score_members': array([0.63313586, 0.63313586, 0.89593583, ..., 0.9364501 , 0.9405816 ,
#        0.9405816 ], shape=(65000,), dtype=float32), 'score_non_members': array([1.        , 0.00686594, 0.01954594, ..., 0.65820354, 0.6576061 ,
#        0.6540302 ], shape=(64998,), dtype=float32), 'score_random': array([0.37869775, 0.09111559, 0.00541641, ..., 0.17705025, 0.02649161,
#        0.02883992], shape=(15000,), dtype=float32), 'score_synthetic': array([0.5741653 , 0.5340904 , 0.8982902 , ..., 0.89185166, 0.8900041 ,
#        0.6332345 ], shape=(15000,), dtype=float32), 'auc': 0.7632472771943278, 'accuracy': 0.4803843136048247, 'precision': np.float64(0.20353570597813445), 'recall': np.float64(0.013461538461538462), 'f1_score': np.float64(0.025252889652087333), 'threshold': np.float32(1.0), 'threshold_method': 'statistical', 'mean_score_members': np.float32(0.8206491), 'mean_score_non_members': np.float32(0.3592209), 'mean_score_random': np.float32(0.09173841), 'mean_score_synthetic': np.float32(0.82346135), 'std_score_members': np.float32(0.12895113), 'std_score_non_members': np.float32(0.41170245), 'std_score_random': np.float32(0.09173841), 'std_score_synthetic': np.float32(0.12169316), 'score_gap_member_non_member': np.float32(0.4614282), 'score_gap_member_random': np.float32(0.7289107), 'score_gap_member_synthetic': np.float32(-0.0028122663), 'privacy_risk_score': np.float32(1.0034269), 'wasserstein_member_synthetic': np.float64(0.007270064454840927), 'wasserstein_nonmember_synthetic': np.float64(0.48312446763479366), 'tp': np.int64(875), 'fp': np.int64(3424), 'tn': np.int64(61574), 'fn': np.int64(64125)}
# Generating Plot 1: Score Distributions...
# Generating Plot 2: ROC and PR Curves...
# Generating Plot 3: Confusion Matrix...
# Saved: teste/ctgan/plots/distributions.pdf
# Saved: teste/ctgan/plots/roc_pr.pdf
# Saved: teste/ctgan/plots/confusion.pdf
# {'score_members': array([0.63313586, 0.63313586, 0.89593583, ..., 0.9364501 , 0.9405816 ,
#         0.9405816 ], shape=(65000,), dtype=float32),
#  'score_non_members': array([1.        , 0.00686594, 0.01954594, ..., 0.65820354, 0.6576061 ,
#         0.6540302 ], shape=(64998,), dtype=float32),
#  'score_random': array([0.37869775, 0.09111559, 0.00541641, ..., 0.17705025, 0.02649161,
#         0.02883992], shape=(15000,), dtype=float32),
#  'score_synthetic': array([0.5741653 , 0.5340904 , 0.8982902 , ..., 0.89185166, 0.8900041 ,
#         0.6332345 ], shape=(15000,), dtype=float32),
#  'auc': 0.7632472771943278,
#  'accuracy': 0.4803843136048247,
#  'precision': np.float64(0.20353570597813445),
#  'recall': np.float64(0.013461538461538462),
#  'f1_score': np.float64(0.025252889652087333),
#  'threshold': np.float32(1.0),
#  'threshold_method': 'statistical',
#  'mean_score_members': np.float32(0.8206491),
#  'mean_score_non_members': np.float32(0.3592209),
#  'mean_score_random': np.float32(0.09173841),
#  'mean_score_synthetic': np.float32(0.82346135),
#  'std_score_members': np.float32(0.12895113),
#  'std_score_non_members': np.float32(0.41170245),
#  'std_score_random': np.float32(0.09173841),
#  'std_score_synthetic': np.float32(0.12169316),
#  'score_gap_member_non_member': np.float32(0.4614282),
#  'score_gap_member_random': np.float32(0.7289107),
#  'score_gap_member_synthetic': np.float32(-0.0028122663),
#  'privacy_risk_score': np.float32(1.0034269),
#  'wasserstein_member_synthetic': np.float64(0.007270064454840927),
#  'wasserstein_nonmember_synthetic': np.float64(0.48312446763479366),
#  'tp': np.int64(875),
#  'fp': np.int64(3424),
#  'tn': np.int64(61574),
#  'fn': np.int64(64125)}

# %%
config_netshare = {
    'member_path': 'datasets/real/cidds_train.csv', # path dos membros
    'non_member_path': 'datasets/reference/ton.csv', # path dos não-membros
    'synth_path': 'datasets/synthetic/netshare.csv', # path dos sintéticos
    'test_path': 'datasets/real/cidds_test.csv', # path do teste
    'categorical_cols': ['proto'], # colunas categóricas
    'numerical_cols': ['srcport', 'dstport', 'td', 'pkt', 'byt'], #colunas numéricas
    'ip_cols': ['srcip', 'dstip'], # colunas de ip
    'label_col': 'label', # nome da coluna do rótulo 
    'batch_size': 200, # número de amostrar por lote
    'num_epochs': 300, # número de épocas
    'fcheckpoint': 100, # frequência para salvar o checkpoint
    'save_path': 'teste2/netshare',    # pasta para salvar resultados
    'use_wgan': True # se deve usar WGAN ou GAN tradicional
}

# %%
import numpy as np
from scipy.stats import gaussian_kde
from sklearn.metrics import roc_auc_score

def domias_attack(train_members, non_members, synthetic_data, reference_data):

    # dataset para avaliar membership
    X_test = np.vstack([train_members, non_members])
    y_test = np.concatenate([
        np.ones(len(train_members)),   # members
        np.zeros(len(non_members))     # non-members
    ])

    # estimar densidade do synthetic dataset -> p_S
    kde_synth = gaussian_kde(synthetic_data.T)

    # estimar densidade do reference dataset -> p_R
    kde_ref = gaussian_kde(reference_data.T)

    p_S = kde_synth(X_test.T)
    p_R = kde_ref(X_test.T)

    # DOMIAS score
    scores = p_S / (p_R + 1e-10)

    auc = roc_auc_score(y_test, scores)

    return scores, auc

# %%
# dataset 
# train | test

# %%
# membros -> modelo generativo -> sintéticos

# membros | não-membros

# %%
# DCR, WGAN, DOMIAS
